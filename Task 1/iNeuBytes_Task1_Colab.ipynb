# %% [markdown]
# # iNeuBytes AI Internship - Task 1
# ## Computer Vision Using CNN Models
# Intern: Guntaka Udaya Mani Rajasekhar Reddy | Registration: INBT021123
#
# Select **Runtime > Change runtime type > T4 GPU** before running all cells.

# %%
# !git clone -q https://github.com/udayreddy0324/internsUdaya_INBT021123_iNeuBytes.git
# %cd /content/internsUdaya_INBT021123_iNeuBytes/Task\ 1
# !pip install -q -r requirements.txt

# %%
import tensorflow as tf
print('TensorFlow:', tf.__version__)
print('GPU:', tf.config.list_physical_devices('GPU'))

# %% [markdown]
# ## Quick pipeline test

# %%
# !python run_task1.py --quick --only baseline

# %% [markdown]
# ## Full baseline and controlled experiments

# %%
# !rm -rf artifacts/*
# !touch artifacts/.gitkeep
# !python run_task1.py --only baseline

# %%
# !python run_task1.py --only dropout batch_norm l2

# %%
# !python run_task1.py --only aug_light aug_moderate aug_aggressive

# %%
# !python run_task1.py --only opt_sgd opt_rmsprop lr_001 lr_0001

# %%
# !python run_task1.py --only deeper kernel_5

# %% [markdown]
# ## Review results, adjust the final configuration if required, then run the final model

# %%
import pandas as pd
results = pd.read_csv('artifacts/master_experiment_table.csv')
display(results.sort_values('test_accuracy', ascending=False))

# %%
# !python run_task1.py --only final

# %% [markdown]
# ## Download all Task 1 deliverables

# %%
# !zip -qr /content/Task1_Final_Deliverables.zip artifacts configs reports src README.md requirements.txt run_task1.py
from google.colab import files
files.download('/content/Task1_Final_Deliverables.zip')
